# %% [markdown]
# # 02 — Video Preprocess (Toy)
#
# Extract frames from the toy video to test the pipeline.

# %%
import os, sys, subprocess, pathlib
frames_dir = '../data/raw/toy/frames'
pathlib.Path(frames_dir).mkdir(parents=True, exist_ok=True)
# !python ../src/preprocess_video.py --video ../data/raw/toy/toy_fall_sim.mp4 --out ../data/raw/toy/frames --fps 10 --width 224 --height 224
len(os.listdir(frames_dir))
