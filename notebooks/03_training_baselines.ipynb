# %% [markdown]
# # 03 — Train CPU Baselines
#
# Train simple classifiers on vitals (Logistic Regression) and toy video frame features (Random Forest).

# %%
# !python ../src/train_baselines.py --vitals ../data/vitals/vitals_train.csv --frames_dir ../data/raw/toy/frames --model_out ../models
